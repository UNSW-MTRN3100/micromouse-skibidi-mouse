# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Open an image
IMAGE_FILE = "continuous_example_2.jpeg"
thresh = 128
maxval = 255

img_maze = cv2.imread(IMAGE_FILE)
img_hsv = cv2.cvtColor(img_maze[260:1950, 480:3425], cv2.COLOR_BGR2HSV)

hsv_mask = cv2.inRange(img_hsv, (4,38,101), (27,255, 255))

_, threshed = cv2.threshold(hsv_mask, thresh, maxval, cv2.THRESH_BINARY)
threshed_3_channel = cv2.cvtColor(threshed, cv2.COLOR_GRAY2BGR)

kernel_size = 5
kernel = np.ones((kernel_size, kernel_size), np.uint8)
threshed_3_channel = cv2.dilate(threshed_3_channel, kernel, iterations = 4)

kernel_size = 3
kernel = np.ones((kernel_size, kernel_size), np.uint8)
threshed_3_channel = cv2.erode(threshed_3_channel, kernel, iterations = 21)

print(threshed_3_channel.shape)
pts1 = np.float32()

# plt.figure(figsize = (9,5))
plt.imshow(threshed_3_channel)
plt.show()
# Out:
# (1690, 2945, 3)

# %%
class Node:
    def __init__(self, node_id, x, y):
        self.id = node_id
        self.x = x
        self.y = y
    
    def get_point(self):
        return (self.x,self.y)
    
    def get_ID(self):
        return self.id

class Graph:
    def __init__(self):
        self.nodes = {}
        self.edges = {}

    def add_node(self, node_id, x, y):
        if node_id not in self.nodes:
            self.nodes[node_id] = Node(node_id, x, y)
            self.edges[node_id] = {}
        pass

    def add_edge(self, node_id1, node_id2, weight):
        if node_id1 in self.nodes and node_id2 in self.nodes:
            self.edges[node_id1][node_id2] = weight
            self.edges[node_id2][node_id1] = weight
        pass

    def remove_edge(self, node_id1, node_id2):
        if node_id1 in self.edges and node_id2 in self.edges[node_id1]:
            del self.edges[node_id1][node_id2]
            del self.edges[node_id2][node_id1]
        pass
    
    def get_nodes(self):
        return self.nodes
    
    def get_edge_weight(self, node_id1, node_id2):
        if node_id1 in self.edges and node_id2 in self.edges[node_id1]:
            return self.edges[node_id1][node_id2]
        return None

# %%
def path_clear(image, x1, y1, x2, y2):
    height, width = image.shape[:2]
    for t in range(101):
        t /= 100.0
        x = int(x1 * (1 - t) + x2 * t)
        y = int(y1 * (1 - t) + y2 * t)
        x = max(0, min(x, width - 1))  # Clamp x
        y = max(0, min(y, height - 1))  # Clamp y
        if (image[y, x][0] == 0 and image[y, x][1] == 0 and image[y, x][2] == 0) or (image[y, x][0] == 255 and image[y, x][1] == 0 and image[y, x][2] == 0):  # Black or red
            return False
    return True

# %%
# Cell 4: Modified Graph Generation with 14x27 Grid and Obstacle Avoidance

bfs_image = threshed_3_channel.copy()
bfs_graph = Graph()

node_id = 0
size_of_node_grid = 20

# Initialize the size of the array
img_width = bfs_image.shape[1]
img_height = bfs_image.shape[0]

# Use original grid spacing
grid_spacing_x = 105
grid_spacing_y = 105

# Get nodes
dictionary = bfs_graph.get_nodes()
height = 14  # 14 rows
width = 27   # 27 columns
border = 150

# Generate nodes
for i in range(height):
    for j in range(width):
        x = border + j * grid_spacing_y
        y = border + i * grid_spacing_x
        bfs_graph.add_node(node_id, x, y)
        node_id += 1

print("Total nodes:", node_id)

# Print all nodes and their coordinates
for node_id, node in dictionary.items():
    print(f"Node ID: {node_id}, Coordinates: {node.get_point()}")

# Add horizontal and vertical edges, considering obstacle avoidance
def is_safe_path(img, x1, y1, x2, y2):
    clearance = 90  # Clearance buffer equal to the robot's size
    return path_clear(img, x1, y1, x2, y2) and (
        all(img[y1-clearance:y1+clearance, x1-clearance:x1+clearance].mean(axis=(0, 1)) > 200) and
        all(img[y2-clearance:y2+clearance, x2-clearance:x2+clearance].mean(axis=(0, 1)) > 200)
    )

for i in range(0, node_id - 1, width):
    for j in range(width - 1):
        node_id1 = i + j
        node_id2 = node_id1 + 1
        if node_id2 < node_id:  # Ensure node_id2 is within bounds
            x1, y1 = dictionary[node_id1].get_point()
            x2, y2 = dictionary[node_id2].get_point()
            if is_safe_path(bfs_image, x1, y1, x2, y2):
                bfs_graph.add_edge(node_id1, node_id2, 1)

for i in range(width):
    for j in range(0, node_id - width, width):
        node_id1 = i + j
        node_id2 = node_id1 + width
        if node_id2 < node_id:  # Ensure node_id2 is within bounds
            x1, y1 = dictionary[node_id1].get_point()
            x2, y2 = dictionary[node_id2].get_point()
            if is_safe_path(bfs_image, x1, y1, x2, y2):
                bfs_graph.add_edge(node_id1, node_id2, 1)

# Print all edges
for node_id, edges in bfs_graph.edges.items():
    for neighbor, weight in edges.items():
        print(f"Edge from {node_id} to {neighbor}, Weight: {weight}")

# Display nodes            
for node_id in dictionary:
    x, y = dictionary[node_id].get_point()
    cv2.circle(bfs_image, (x, y), 5, (0, 255, 0), -1)

# Display Resulting Image
plt.imshow(bfs_image)
plt.show()
# Out:
# Total nodes: 378
# Node ID: 0, Coordinates: (150, 150)
# Node ID: 1, Coordinates: (255, 150)
# Node ID: 2, Coordinates: (360, 150)
# Node ID: 3, Coordinates: (465, 150)
# Node ID: 4, Coordinates: (570, 150)
# Node ID: 5, Coordinates: (675, 150)
# Node ID: 6, Coordinates: (780, 150)
# Node ID: 7, Coordinates: (885, 150)
# Node ID: 8, Coordinates: (990, 150)
# Node ID: 9, Coordinates: (1095, 150)
# Node ID: 10, Coordinates: (1200, 150)
# Node ID: 11, Coordinates: (1305, 150)
# Node ID: 12, Coordinates: (1410, 150)
# Node ID: 13, Coordinates: (1515, 150)
# Node ID: 14, Coordinates: (1620, 150)
# Node ID: 15, Coordinates: (1725, 150)
# Node ID: 16, Coordinates: (1830, 150)
# Node ID: 17, Coordinates: (1935, 150)
# Node ID: 18, Coordinates: (2040, 150)
# Node ID: 19, Coordinates: (2145, 150)
# Node ID: 20, Coordinates: (2250, 150)
# Node ID: 21, Coordinates: (2355, 150)
# Node ID: 22, Coordinates: (2460, 150)
# Node ID: 23, Coordinates: (2565, 150)
# Node ID: 24, Coordinates: (2670, 150)
# Node ID: 25, Coordinates: (2775, 150)
# Node ID: 26, Coordinates: (2880, 150)
# Node ID: 27, Coordinates: (150, 255)
# Node ID: 28, Coordinates: (255, 255)
# Node ID: 29, Coordinates: (360, 255)
# Node ID: 30, Coordinates: (465, 255)
# Node ID: 31, Coordinates: (570, 255)
# Node ID: 32, Coordinates: (675, 255)
# Node ID: 33, Coordinates: (780, 255)
# Node ID: 34, Coordinates: (885, 255)
# Node ID: 35, Coordinates: (990, 255)
# Node ID: 36, Coordinates: (1095, 255)
# Node ID: 37, Coordinates: (1200, 255)
# Node ID: 38, Coordinates: (1305, 255)
# Node ID: 39, Coordinates: (1410, 255)
# Node ID: 40, Coordinates: (1515, 255)
# Node ID: 41, Coordinates: (1620, 255)
# Node ID: 42, Coordinates: (1725, 255)
# Node ID: 43, Coordinates: (1830, 255)
# Node ID: 44, Coordinates: (1935, 255)
# Node ID: 45, Coordinates: (2040, 255)
# Node ID: 46, Coordinates: (2145, 255)
# Node ID: 47, Coordinates: (2250, 255)
# Node ID: 48, Coordinates: (2355, 255)
# Node ID: 49, Coordinates: (2460, 255)
# Node ID: 50, Coordinates: (2565, 255)
# Node ID: 51, Coordinates: (2670, 255)
# Node ID: 52, Coordinates: (2775, 255)
# Node ID: 53, Coordinates: (2880, 255)
# Node ID: 54, Coordinates: (150, 360)
# Node ID: 55, Coordinates: (255, 360)
# Node ID: 56, Coordinates: (360, 360)
# Node ID: 57, Coordinates: (465, 360)
# Node ID: 58, Coordinates: (570, 360)
# Node ID: 59, Coordinates: (675, 360)
# Node ID: 60, Coordinates: (780, 360)
# Node ID: 61, Coordinates: (885, 360)
# Node ID: 62, Coordinates: (990, 360)
# Node ID: 63, Coordinates: (1095, 360)
# Node ID: 64, Coordinates: (1200, 360)
# Node ID: 65, Coordinates: (1305, 360)
# Node ID: 66, Coordinates: (1410, 360)
# Node ID: 67, Coordinates: (1515, 360)
# Node ID: 68, Coordinates: (1620, 360)
# Node ID: 69, Coordinates: (1725, 360)
# Node ID: 70, Coordinates: (1830, 360)
# Node ID: 71, Coordinates: (1935, 360)
# Node ID: 72, Coordinates: (2040, 360)
# Node ID: 73, Coordinates: (2145, 360)
# Node ID: 74, Coordinates: (2250, 360)
# Node ID: 75, Coordinates: (2355, 360)
# Node ID: 76, Coordinates: (2460, 360)
# Node ID: 77, Coordinates: (2565, 360)
# Node ID: 78, Coordinates: (2670, 360)
# Node ID: 79, Coordinates: (2775, 360)
# Node ID: 80, Coordinates: (2880, 360)
# Node ID: 81, Coordinates: (150, 465)
# Node ID: 82, Coordinates: (255, 465)
# Node ID: 83, Coordinates: (360, 465)
# Node ID: 84, Coordinates: (465, 465)
# Node ID: 85, Coordinates: (570, 465)
# Node ID: 86, Coordinates: (675, 465)
# Node ID: 87, Coordinates: (780, 465)
# Node ID: 88, Coordinates: (885, 465)
# Node ID: 89, Coordinates: (990, 465)
# Node ID: 90, Coordinates: (1095, 465)
# Node ID: 91, Coordinates: (1200, 465)
# Node ID: 92, Coordinates: (1305, 465)
# Node ID: 93, Coordinates: (1410, 465)
# Node ID: 354, Coordinates: (465, 1515)
# Node ID: 355, Coordinates: (570, 1515)
# Node ID: 356, Coordinates: (675, 1515)
# Node ID: 357, Coordinates: (780, 1515)
# Node ID: 358, Coordinates: (885, 1515)
# Node ID: 359, Coordinates: (990, 1515)
# Node ID: 360, Coordinates: (1095, 1515)
# Node ID: 361, Coordinates: (1200, 1515)
# Node ID: 362, Coordinates: (1305, 1515)
# Node ID: 363, Coordinates: (1410, 1515)
# Node ID: 364, Coordinates: (1515, 1515)
# Node ID: 365, Coordinates: (1620, 1515)
# Node ID: 366, Coordinates: (1725, 1515)
# Node ID: 367, Coordinates: (1830, 1515)
# Node ID: 368, Coordinates: (1935, 1515)
# Node ID: 369, Coordinates: (2040, 1515)
# Node ID: 370, Coordinates: (2145, 1515)
# Node ID: 371, Coordinates: (2250, 1515)
# Node ID: 372, Coordinates: (2355, 1515)
# Node ID: 373, Coordinates: (2460, 1515)
# Node ID: 374, Coordinates: (2565, 1515)
# Node ID: 375, Coordinates: (2670, 1515)
# Node ID: 376, Coordinates: (2775, 1515)
# Node ID: 377, Coordinates: (2880, 1515)
# Edge from 0 to 27, Weight: 1
# Edge from 6 to 7, Weight: 1
# Edge from 7 to 6, Weight: 1
# Edge from 7 to 8, Weight: 1
# Edge from 7 to 34, Weight: 1
# Edge from 8 to 7, Weight: 1
# Edge from 8 to 9, Weight: 1
# Edge from 8 to 35, Weight: 1
# Edge from 9 to 8, Weight: 1
# Edge from 9 to 10, Weight: 1
# Edge from 9 to 36, Weight: 1
# Edge from 10 to 9, Weight: 1
# Edge from 10 to 11, Weight: 1
# Edge from 10 to 37, Weight: 1
# Edge from 11 to 10, Weight: 1
# Edge from 11 to 12, Weight: 1
# Edge from 11 to 38, Weight: 1
# Edge from 12 to 11, Weight: 1
# Edge from 12 to 13, Weight: 1
# Edge from 12 to 39, Weight: 1
# Edge from 13 to 12, Weight: 1
# Edge from 13 to 14, Weight: 1
# Edge from 13 to 40, Weight: 1
# Edge from 14 to 13, Weight: 1
# Edge from 14 to 15, Weight: 1
# Edge from 14 to 41, Weight: 1
# Edge from 15 to 14, Weight: 1
# Edge from 15 to 16, Weight: 1
# Edge from 15 to 42, Weight: 1
# Edge from 16 to 15, Weight: 1
# Edge from 16 to 17, Weight: 1
# Edge from 16 to 43, Weight: 1
# Edge from 17 to 16, Weight: 1
# Edge from 17 to 18, Weight: 1
# Edge from 17 to 44, Weight: 1
# Edge from 18 to 17, Weight: 1
# Edge from 18 to 19, Weight: 1
# Edge from 18 to 45, Weight: 1
# Edge from 19 to 18, Weight: 1
# Edge from 19 to 20, Weight: 1
# Edge from 19 to 46, Weight: 1
# Edge from 20 to 19, Weight: 1
# Edge from 20 to 21, Weight: 1
# Edge from 20 to 47, Weight: 1
# Edge from 21 to 20, Weight: 1
# Edge from 25 to 26, Weight: 1
# Edge from 25 to 52, Weight: 1
# Edge from 26 to 25, Weight: 1
# Edge from 26 to 53, Weight: 1
# Edge from 27 to 0, Weight: 1
# Edge from 27 to 54, Weight: 1
# Edge from 34 to 35, Weight: 1
# Edge from 34 to 7, Weight: 1
# Edge from 34 to 61, Weight: 1
# Edge from 35 to 34, Weight: 1
# Edge from 35 to 36, Weight: 1
# Edge from 35 to 8, Weight: 1
# Edge from 36 to 35, Weight: 1
# Edge from 36 to 37, Weight: 1
# Edge from 36 to 9, Weight: 1
# Edge from 37 to 36, Weight: 1
# Edge from 37 to 38, Weight: 1
# Edge from 37 to 10, Weight: 1
# Edge from 38 to 37, Weight: 1
# Edge from 38 to 39, Weight: 1
# Edge from 38 to 11, Weight: 1
# Edge from 39 to 38, Weight: 1
# Edge from 39 to 40, Weight: 1
# Edge from 39 to 12, Weight: 1
# Edge from 39 to 66, Weight: 1
# Edge from 40 to 39, Weight: 1
# Edge from 40 to 41, Weight: 1
# Edge from 40 to 13, Weight: 1
# Edge from 40 to 67, Weight: 1
# Edge from 41 to 40, Weight: 1
# Edge from 41 to 42, Weight: 1
# Edge from 41 to 14, Weight: 1
# Edge from 42 to 41, Weight: 1
# Edge from 42 to 43, Weight: 1
# Edge from 42 to 15, Weight: 1
# Edge from 42 to 69, Weight: 1
# Edge from 43 to 42, Weight: 1
# Edge from 43 to 44, Weight: 1
# Edge from 43 to 16, Weight: 1
# Edge from 43 to 70, Weight: 1
# Edge from 44 to 43, Weight: 1
# Edge from 44 to 45, Weight: 1
# Edge from 44 to 17, Weight: 1
# Edge from 44 to 71, Weight: 1
# Edge from 45 to 44, Weight: 1
# Edge from 45 to 46, Weight: 1
# Edge from 45 to 18, Weight: 1
# Edge from 45 to 72, Weight: 1
# Edge from 46 to 45, Weight: 1
# Edge from 46 to 47, Weight: 1
# Edge from 46 to 19, Weight: 1
# Edge from 46 to 73, Weight: 1
# Edge from 47 to 46, Weight: 1
# Edge from 47 to 20, Weight: 1
# Edge from 52 to 53, Weight: 1
# Edge from 52 to 25, Weight: 1
# Edge from 52 to 79, Weight: 1
# Edge from 53 to 52, Weight: 1
# Edge from 53 to 26, Weight: 1
# Edge from 53 to 80, Weight: 1
# Edge from 54 to 27, Weight: 1
# Edge from 54 to 81, Weight: 1
# Edge from 61 to 34, Weight: 1
# Edge from 61 to 88, Weight: 1
# Edge from 66 to 67, Weight: 1
# Edge from 66 to 39, Weight: 1
# Edge from 66 to 93, Weight: 1
# Edge from 67 to 66, Weight: 1
# Edge from 67 to 40, Weight: 1
# Edge from 67 to 94, Weight: 1
# Edge from 69 to 70, Weight: 1
# Edge from 69 to 42, Weight: 1
# Edge from 69 to 96, Weight: 1
# Edge from 70 to 69, Weight: 1
# Edge from 70 to 71, Weight: 1
# Edge from 70 to 43, Weight: 1
# Edge from 70 to 97, Weight: 1
# Edge from 71 to 70, Weight: 1
# Edge from 71 to 72, Weight: 1
# Edge from 71 to 44, Weight: 1
# Edge from 71 to 98, Weight: 1
# Edge from 72 to 71, Weight: 1
# Edge from 72 to 73, Weight: 1
# Edge from 72 to 45, Weight: 1
# Edge from 72 to 99, Weight: 1
# Edge from 73 to 72, Weight: 1
# Edge from 73 to 46, Weight: 1
# Edge from 73 to 100, Weight: 1
# Edge from 79 to 80, Weight: 1
# Edge from 79 to 52, Weight: 1
# Edge from 79 to 106, Weight: 1
# Edge from 80 to 79, Weight: 1
# Edge from 80 to 53, Weight: 1
# Edge from 80 to 107, Weight: 1
# Edge from 81 to 54, Weight: 1
# Edge from 81 to 108, Weight: 1
# Edge from 88 to 61, Weight: 1
# Edge from 88 to 115, Weight: 1
# Edge from 93 to 94, Weight: 1
# Edge from 93 to 66, Weight: 1
# Edge from 93 to 120, Weight: 1
# Edge from 94 to 93, Weight: 1
# Edge from 94 to 67, Weight: 1
# Edge from 94 to 121, Weight: 1
# Edge from 96 to 97, Weight: 1
# Edge from 96 to 69, Weight: 1
# Edge from 96 to 123, Weight: 1
# Edge from 97 to 96, Weight: 1
# Edge from 97 to 98, Weight: 1
# Edge from 97 to 70, Weight: 1
# Edge from 97 to 124, Weight: 1
# Edge from 98 to 97, Weight: 1
# Edge from 98 to 99, Weight: 1
# Edge from 98 to 71, Weight: 1
# Edge from 99 to 98, Weight: 1
# Edge from 99 to 100, Weight: 1
# Edge from 99 to 72, Weight: 1
# Edge from 100 to 99, Weight: 1
# Edge from 100 to 101, Weight: 1
# Edge from 100 to 73, Weight: 1
# Edge from 100 to 127, Weight: 1
# Edge from 101 to 100, Weight: 1
# Edge from 101 to 102, Weight: 1
# Edge from 101 to 128, Weight: 1
# Edge from 102 to 101, Weight: 1
# Edge from 102 to 129, Weight: 1
# Edge from 106 to 107, Weight: 1
# Edge from 106 to 79, Weight: 1
# Edge from 106 to 133, Weight: 1
# Edge from 107 to 106, Weight: 1
# Edge from 107 to 80, Weight: 1
# Edge from 107 to 134, Weight: 1
# Edge from 108 to 81, Weight: 1
# Edge from 108 to 135, Weight: 1
# Edge from 115 to 88, Weight: 1
# Edge from 115 to 142, Weight: 1
# Edge from 117 to 118, Weight: 1
# Edge from 117 to 144, Weight: 1
# Edge from 118 to 117, Weight: 1
# Edge from 118 to 145, Weight: 1
# Edge from 120 to 121, Weight: 1
# Edge from 120 to 93, Weight: 1
# Edge from 120 to 147, Weight: 1
# Edge from 121 to 120, Weight: 1
# Edge from 121 to 94, Weight: 1
# Edge from 121 to 148, Weight: 1
# Edge from 123 to 124, Weight: 1
# Edge from 123 to 96, Weight: 1
# Edge from 123 to 150, Weight: 1
# Edge from 124 to 123, Weight: 1
# Edge from 124 to 97, Weight: 1
# Edge from 124 to 151, Weight: 1
# Edge from 127 to 128, Weight: 1
# Edge from 127 to 100, Weight: 1
# Edge from 127 to 154, Weight: 1
# Edge from 128 to 127, Weight: 1
# Edge from 128 to 129, Weight: 1
# Edge from 128 to 101, Weight: 1
# Edge from 128 to 155, Weight: 1
# Edge from 129 to 128, Weight: 1
# Edge from 129 to 102, Weight: 1
# Edge from 129 to 156, Weight: 1
# Edge from 133 to 134, Weight: 1
# Edge from 133 to 106, Weight: 1
# Edge from 133 to 160, Weight: 1
# Edge from 134 to 133, Weight: 1
# Edge from 134 to 107, Weight: 1
# Edge from 134 to 161, Weight: 1
# Edge from 135 to 108, Weight: 1
# Edge from 135 to 162, Weight: 1
# Edge from 142 to 115, Weight: 1
# Edge from 142 to 169, Weight: 1
# Edge from 144 to 145, Weight: 1
# Edge from 144 to 117, Weight: 1
# Edge from 144 to 171, Weight: 1
# Edge from 145 to 144, Weight: 1
# Edge from 145 to 118, Weight: 1
# Edge from 145 to 172, Weight: 1
# Edge from 147 to 148, Weight: 1
# Edge from 147 to 120, Weight: 1
# Edge from 147 to 174, Weight: 1
# Edge from 148 to 147, Weight: 1
# Edge from 148 to 121, Weight: 1
# Edge from 148 to 175, Weight: 1
# Edge from 150 to 151, Weight: 1
# Edge from 150 to 123, Weight: 1
# Edge from 150 to 177, Weight: 1
# Edge from 151 to 150, Weight: 1
# Edge from 151 to 124, Weight: 1
# Edge from 151 to 178, Weight: 1
# Edge from 154 to 155, Weight: 1
# Edge from 154 to 127, Weight: 1
# Edge from 154 to 181, Weight: 1
# Edge from 155 to 154, Weight: 1
# Edge from 155 to 156, Weight: 1
# Edge from 155 to 128, Weight: 1
# Edge from 155 to 182, Weight: 1
# Edge from 156 to 155, Weight: 1
# Edge from 156 to 129, Weight: 1
# Edge from 156 to 183, Weight: 1
# Edge from 160 to 161, Weight: 1
# Edge from 160 to 133, Weight: 1
# Edge from 160 to 187, Weight: 1
# Edge from 161 to 160, Weight: 1
# Edge from 161 to 134, Weight: 1
# Edge from 161 to 188, Weight: 1
# Edge from 162 to 135, Weight: 1
# Edge from 162 to 189, Weight: 1
# Edge from 169 to 170, Weight: 1
# Edge from 169 to 142, Weight: 1
# Edge from 169 to 196, Weight: 1
# Edge from 170 to 169, Weight: 1
# Edge from 170 to 171, Weight: 1
# Edge from 170 to 197, Weight: 1
# Edge from 171 to 170, Weight: 1
# Edge from 171 to 172, Weight: 1
# Edge from 171 to 144, Weight: 1
# Edge from 171 to 198, Weight: 1
# Edge from 172 to 171, Weight: 1
# Edge from 172 to 145, Weight: 1
# Edge from 172 to 199, Weight: 1
# Edge from 174 to 175, Weight: 1
# Edge from 174 to 147, Weight: 1
# Edge from 174 to 201, Weight: 1
# Edge from 175 to 174, Weight: 1
# Edge from 175 to 148, Weight: 1
# Edge from 175 to 202, Weight: 1
# Edge from 177 to 178, Weight: 1
# Edge from 177 to 150, Weight: 1
# Edge from 178 to 177, Weight: 1
# Edge from 178 to 151, Weight: 1
# Edge from 180 to 181, Weight: 1
# Edge from 180 to 207, Weight: 1
# Edge from 181 to 180, Weight: 1
# Edge from 181 to 182, Weight: 1
# Edge from 181 to 154, Weight: 1
# Edge from 181 to 208, Weight: 1
# Edge from 182 to 181, Weight: 1
# Edge from 182 to 183, Weight: 1
# Edge from 182 to 155, Weight: 1
# Edge from 182 to 209, Weight: 1
# Edge from 183 to 182, Weight: 1
# Edge from 183 to 156, Weight: 1
# Edge from 183 to 210, Weight: 1
# Edge from 187 to 188, Weight: 1
# Edge from 187 to 160, Weight: 1
# Edge from 187 to 214, Weight: 1
# Edge from 188 to 187, Weight: 1
# Edge from 188 to 161, Weight: 1
# Edge from 188 to 215, Weight: 1
# Edge from 189 to 162, Weight: 1
# Edge from 189 to 216, Weight: 1
# Edge from 196 to 197, Weight: 1
# Edge from 196 to 169, Weight: 1
# Edge from 196 to 223, Weight: 1
# Edge from 197 to 196, Weight: 1
# Edge from 197 to 198, Weight: 1
# Edge from 197 to 170, Weight: 1
# Edge from 198 to 197, Weight: 1
# Edge from 198 to 199, Weight: 1
# Edge from 198 to 171, Weight: 1
# Edge from 199 to 198, Weight: 1
# Edge from 199 to 172, Weight: 1
# Edge from 201 to 202, Weight: 1
# Edge from 201 to 174, Weight: 1
# Edge from 202 to 201, Weight: 1
# Edge from 202 to 175, Weight: 1
# Edge from 206 to 207, Weight: 1
# Edge from 206 to 233, Weight: 1
# Edge from 207 to 206, Weight: 1
# Edge from 207 to 208, Weight: 1
# Edge from 207 to 180, Weight: 1
# Edge from 207 to 234, Weight: 1
# Edge from 208 to 207, Weight: 1
# Edge from 208 to 209, Weight: 1
# Edge from 208 to 181, Weight: 1
# Edge from 208 to 235, Weight: 1
# Edge from 209 to 208, Weight: 1
# Edge from 209 to 210, Weight: 1
# Edge from 209 to 182, Weight: 1
# Edge from 209 to 236, Weight: 1
# Edge from 210 to 209, Weight: 1
# Edge from 210 to 183, Weight: 1
# Edge from 210 to 237, Weight: 1
# Edge from 214 to 215, Weight: 1
# Edge from 214 to 187, Weight: 1
# Edge from 214 to 241, Weight: 1
# Edge from 215 to 214, Weight: 1
# Edge from 215 to 188, Weight: 1
# Edge from 215 to 242, Weight: 1
# Edge from 216 to 189, Weight: 1
# Edge from 216 to 243, Weight: 1
# Edge from 222 to 223, Weight: 1
# Edge from 222 to 249, Weight: 1
# Edge from 223 to 222, Weight: 1
# Edge from 223 to 196, Weight: 1
# Edge from 223 to 250, Weight: 1
# Edge from 233 to 234, Weight: 1
# Edge from 233 to 206, Weight: 1
# Edge from 233 to 260, Weight: 1
# Edge from 234 to 233, Weight: 1
# Edge from 234 to 235, Weight: 1
# Edge from 234 to 207, Weight: 1
# Edge from 234 to 261, Weight: 1
# Edge from 235 to 234, Weight: 1
# Edge from 235 to 236, Weight: 1
# Edge from 235 to 208, Weight: 1
# Edge from 235 to 262, Weight: 1
# Edge from 236 to 235, Weight: 1
# Edge from 236 to 237, Weight: 1
# Edge from 236 to 209, Weight: 1
# Edge from 237 to 236, Weight: 1
# Edge from 237 to 210, Weight: 1
# Edge from 241 to 242, Weight: 1
# Edge from 241 to 214, Weight: 1
# Edge from 241 to 268, Weight: 1
# Edge from 242 to 241, Weight: 1
# Edge from 242 to 215, Weight: 1
# Edge from 242 to 269, Weight: 1
# Edge from 243 to 216, Weight: 1
# Edge from 243 to 270, Weight: 1
# Edge from 247 to 248, Weight: 1
# Edge from 247 to 274, Weight: 1
# Edge from 248 to 247, Weight: 1
# Edge from 248 to 249, Weight: 1
# Edge from 248 to 275, Weight: 1
# Edge from 249 to 248, Weight: 1
# Edge from 249 to 250, Weight: 1
# Edge from 249 to 222, Weight: 1
# Edge from 249 to 276, Weight: 1
# Edge from 250 to 249, Weight: 1
# Edge from 250 to 251, Weight: 1
# Edge from 250 to 223, Weight: 1
# Edge from 250 to 277, Weight: 1
# Edge from 251 to 250, Weight: 1
# Edge from 251 to 252, Weight: 1
# Edge from 251 to 278, Weight: 1
# Edge from 252 to 251, Weight: 1
# Edge from 252 to 279, Weight: 1
# Edge from 255 to 282, Weight: 1
# Edge from 260 to 261, Weight: 1
# Edge from 260 to 233, Weight: 1
# Edge from 260 to 287, Weight: 1
# Edge from 261 to 260, Weight: 1
# Edge from 261 to 262, Weight: 1
# Edge from 261 to 234, Weight: 1
# Edge from 261 to 288, Weight: 1
# Edge from 262 to 261, Weight: 1
# Edge from 262 to 235, Weight: 1
# Edge from 268 to 269, Weight: 1
# Edge from 268 to 241, Weight: 1
# Edge from 268 to 295, Weight: 1
# Edge from 269 to 268, Weight: 1
# Edge from 269 to 242, Weight: 1
# Edge from 269 to 296, Weight: 1
# Edge from 270 to 243, Weight: 1
# Edge from 270 to 297, Weight: 1
# Edge from 274 to 275, Weight: 1
# Edge from 274 to 247, Weight: 1
# Edge from 275 to 274, Weight: 1
# Edge from 275 to 276, Weight: 1
# Edge from 275 to 248, Weight: 1
# Edge from 276 to 275, Weight: 1
# Edge from 276 to 277, Weight: 1
# Edge from 276 to 249, Weight: 1
# Edge from 276 to 303, Weight: 1
# Edge from 277 to 276, Weight: 1
# Edge from 277 to 278, Weight: 1
# Edge from 277 to 250, Weight: 1
# Edge from 277 to 304, Weight: 1
# Edge from 278 to 277, Weight: 1
# Edge from 278 to 279, Weight: 1
# Edge from 278 to 251, Weight: 1
# Edge from 278 to 305, Weight: 1
# Edge from 279 to 278, Weight: 1
# Edge from 279 to 280, Weight: 1
# Edge from 279 to 252, Weight: 1
# Edge from 279 to 306, Weight: 1
# Edge from 280 to 279, Weight: 1
# Edge from 280 to 307, Weight: 1
# Edge from 282 to 283, Weight: 1
# Edge from 282 to 255, Weight: 1
# Edge from 283 to 282, Weight: 1
# Edge from 285 to 286, Weight: 1
# Edge from 285 to 312, Weight: 1
# Edge from 286 to 285, Weight: 1
# Edge from 286 to 287, Weight: 1
# Edge from 286 to 313, Weight: 1
# Edge from 287 to 286, Weight: 1
# Edge from 287 to 288, Weight: 1
# Edge from 287 to 260, Weight: 1
# Edge from 287 to 314, Weight: 1
# Edge from 288 to 287, Weight: 1
# Edge from 288 to 261, Weight: 1
# Edge from 288 to 315, Weight: 1
# Edge from 295 to 296, Weight: 1
# Edge from 295 to 268, Weight: 1
# Edge from 295 to 322, Weight: 1
# Edge from 296 to 295, Weight: 1
# Edge from 296 to 269, Weight: 1
# Edge from 296 to 323, Weight: 1
# Edge from 297 to 270, Weight: 1
# Edge from 297 to 324, Weight: 1
# Edge from 303 to 304, Weight: 1
# Edge from 303 to 276, Weight: 1
# Edge from 303 to 330, Weight: 1
# Edge from 304 to 303, Weight: 1
# Edge from 304 to 305, Weight: 1
# Edge from 304 to 277, Weight: 1
# Edge from 304 to 331, Weight: 1
# Edge from 305 to 304, Weight: 1
# Edge from 305 to 306, Weight: 1
# Edge from 305 to 278, Weight: 1
# Edge from 305 to 332, Weight: 1
# Edge from 306 to 305, Weight: 1
# Edge from 306 to 307, Weight: 1
# Edge from 306 to 279, Weight: 1
# Edge from 306 to 333, Weight: 1
# Edge from 307 to 306, Weight: 1
# Edge from 307 to 280, Weight: 1
# Edge from 307 to 334, Weight: 1
# Edge from 312 to 313, Weight: 1
# Edge from 312 to 285, Weight: 1
# Edge from 312 to 339, Weight: 1
# Edge from 313 to 312, Weight: 1
# Edge from 313 to 314, Weight: 1
# Edge from 313 to 286, Weight: 1
# Edge from 313 to 340, Weight: 1
# Edge from 314 to 313, Weight: 1
# Edge from 314 to 315, Weight: 1
# Edge from 314 to 287, Weight: 1
# Edge from 314 to 341, Weight: 1
# Edge from 315 to 314, Weight: 1
# Edge from 315 to 316, Weight: 1
# Edge from 315 to 288, Weight: 1
# Edge from 315 to 342, Weight: 1
# Edge from 316 to 315, Weight: 1
# Edge from 316 to 343, Weight: 1
# Edge from 322 to 323, Weight: 1
# Edge from 322 to 295, Weight: 1
# Edge from 322 to 349, Weight: 1
# Edge from 323 to 322, Weight: 1
# Edge from 323 to 296, Weight: 1
# Edge from 323 to 350, Weight: 1
# Edge from 324 to 325, Weight: 1
# Edge from 324 to 297, Weight: 1
# Edge from 324 to 351, Weight: 1
# Edge from 325 to 324, Weight: 1
# Edge from 325 to 352, Weight: 1
# Edge from 329 to 330, Weight: 1
# Edge from 329 to 356, Weight: 1
# Edge from 330 to 329, Weight: 1
# Edge from 330 to 331, Weight: 1
# Edge from 330 to 303, Weight: 1
# Edge from 330 to 357, Weight: 1
# Edge from 331 to 330, Weight: 1
# Edge from 331 to 332, Weight: 1
# Edge from 331 to 304, Weight: 1
# Edge from 331 to 358, Weight: 1
# Edge from 332 to 331, Weight: 1
# Edge from 332 to 333, Weight: 1
# Edge from 332 to 305, Weight: 1
# Edge from 332 to 359, Weight: 1
# Edge from 333 to 332, Weight: 1
# Edge from 333 to 334, Weight: 1
# Edge from 333 to 306, Weight: 1
# Edge from 333 to 360, Weight: 1
# Edge from 334 to 333, Weight: 1
# Edge from 334 to 335, Weight: 1
# Edge from 334 to 307, Weight: 1
# Edge from 334 to 361, Weight: 1
# Edge from 335 to 334, Weight: 1
# Edge from 335 to 362, Weight: 1
# Edge from 339 to 340, Weight: 1
# Edge from 339 to 312, Weight: 1
# Edge from 339 to 366, Weight: 1
# Edge from 340 to 339, Weight: 1
# Edge from 340 to 341, Weight: 1
# Edge from 340 to 313, Weight: 1
# Edge from 340 to 367, Weight: 1
# Edge from 341 to 340, Weight: 1
# Edge from 341 to 342, Weight: 1
# Edge from 341 to 314, Weight: 1
# Edge from 341 to 368, Weight: 1
# Edge from 342 to 341, Weight: 1
# Edge from 342 to 343, Weight: 1
# Edge from 342 to 315, Weight: 1
# Edge from 342 to 369, Weight: 1
# Edge from 343 to 342, Weight: 1
# Edge from 343 to 344, Weight: 1
# Edge from 343 to 316, Weight: 1
# Edge from 343 to 370, Weight: 1
# Edge from 344 to 343, Weight: 1
# Edge from 344 to 345, Weight: 1
# Edge from 344 to 371, Weight: 1
# Edge from 345 to 344, Weight: 1
# Edge from 345 to 346, Weight: 1
# Edge from 345 to 372, Weight: 1
# Edge from 346 to 345, Weight: 1
# Edge from 346 to 373, Weight: 1
# Edge from 348 to 349, Weight: 1
# Edge from 348 to 375, Weight: 1
# Edge from 349 to 348, Weight: 1
# Edge from 349 to 350, Weight: 1
# Edge from 349 to 322, Weight: 1
# Edge from 349 to 376, Weight: 1
# Edge from 350 to 349, Weight: 1
# Edge from 350 to 323, Weight: 1
# Edge from 351 to 352, Weight: 1
# Edge from 351 to 324, Weight: 1
# Edge from 352 to 351, Weight: 1
# Edge from 352 to 353, Weight: 1
# Edge from 352 to 325, Weight: 1
# Edge from 353 to 352, Weight: 1
# Edge from 353 to 354, Weight: 1
# Edge from 354 to 353, Weight: 1
# Edge from 354 to 355, Weight: 1
# Edge from 355 to 354, Weight: 1
# Edge from 355 to 356, Weight: 1
# Edge from 356 to 355, Weight: 1
# Edge from 356 to 357, Weight: 1
# Edge from 356 to 329, Weight: 1
# Edge from 357 to 356, Weight: 1
# Edge from 357 to 358, Weight: 1
# Edge from 357 to 330, Weight: 1
# Edge from 358 to 357, Weight: 1
# Edge from 358 to 359, Weight: 1
# Edge from 358 to 331, Weight: 1
# Edge from 359 to 358, Weight: 1
# Edge from 359 to 360, Weight: 1
# Edge from 359 to 332, Weight: 1
# Edge from 360 to 359, Weight: 1
# Edge from 360 to 361, Weight: 1
# Edge from 360 to 333, Weight: 1
# Edge from 361 to 360, Weight: 1
# Edge from 361 to 362, Weight: 1
# Edge from 361 to 334, Weight: 1
# Edge from 362 to 361, Weight: 1
# Edge from 362 to 363, Weight: 1
# Edge from 362 to 335, Weight: 1
# Edge from 363 to 362, Weight: 1
# Edge from 363 to 364, Weight: 1
# Edge from 364 to 363, Weight: 1
# Edge from 366 to 367, Weight: 1
# Edge from 366 to 339, Weight: 1
# Edge from 367 to 366, Weight: 1
# Edge from 367 to 368, Weight: 1
# Edge from 367 to 340, Weight: 1
# Edge from 368 to 367, Weight: 1
# Edge from 368 to 369, Weight: 1
# Edge from 368 to 341, Weight: 1
# Edge from 369 to 368, Weight: 1
# Edge from 369 to 370, Weight: 1
# Edge from 369 to 342, Weight: 1
# Edge from 370 to 369, Weight: 1
# Edge from 370 to 371, Weight: 1
# Edge from 370 to 343, Weight: 1
# Edge from 371 to 370, Weight: 1
# Edge from 371 to 372, Weight: 1
# Edge from 371 to 344, Weight: 1
# Edge from 372 to 371, Weight: 1
# Edge from 372 to 373, Weight: 1
# Edge from 372 to 345, Weight: 1
# Edge from 373 to 372, Weight: 1
# Edge from 373 to 374, Weight: 1
# Edge from 373 to 346, Weight: 1
# Edge from 374 to 373, Weight: 1
# Edge from 374 to 375, Weight: 1
# Edge from 375 to 374, Weight: 1
# Edge from 375 to 376, Weight: 1
# Edge from 375 to 348, Weight: 1
# Edge from 376 to 375, Weight: 1
# Edge from 376 to 349, Weight: 1

# %%
# Cell 5: Using Directly Specified Node IDs

# Directly specify the start and goal node IDs based on your observation
start_id = 0  # Updated based on your observation
goal_id = 26  # Updated based on your observation

# Ensure node_id is within bounds and check node coordinates
if start_id >= len(dictionary) or goal_id >= len(dictionary):
    print(f"Invalid node IDs. Start ID: {start_id}, Goal ID: {goal_id}")
else:
    print(f"Start ID: {start_id}, Goal ID: {goal_id}")
    print(f"Start Coordinates: {dictionary[start_id].get_point()}, Goal Coordinates: {dictionary[goal_id].get_point()}")

    # Check if start and goal nodes are connected to neighbors
    print(f"Start Node Edges: {bfs_graph.edges.get(start_id, 'No connections')}")
    print(f"Goal Node Edges: {bfs_graph.edges.get(goal_id, 'No connections')}")

    # BFS Pathfinding
    def bfs(graph, start, goal):
        from collections import deque
        queue = deque([start])
        visited = {start: None}
        
        while queue:
            current = queue.popleft()
            
            if current == goal:
                path = []
                while current is not None:
                    path.append(current)
                    current = visited[current]
                return path[::-1]  # Reverse the path
            
            for neighbor in graph.edges[current]:
                if neighbor not in visited:
                    visited[neighbor] = current
                    queue.append(neighbor)
        
        return None

    # Perform BFS
    path = bfs(bfs_graph, start_id, goal_id)

    if path:
        # Draw the path
        for i in range(len(path) - 1):
            node_id1 = path[i]
            node_id2 = path[i + 1]

            # Ensure node_id1 and node_id2 are connected
            if node_id2 in bfs_graph.edges[node_id1]:
                x1, y1 = dictionary[node_id1].get_point()
                x2, y2 = dictionary[node_id2].get_point()
                cv2.line(bfs_image, (x1, y1), (x2, y2), (255, 0, 0), 2)  # Draw path in blue

        plt.imshow(bfs_image)
        plt.show()
    else:
        print("No path found")

    # Check connections along the path
    if path:
        for i in range(len(path) - 1):
            print(f"Connection: {path[i]} -> {path[i+1]}")
# Out:
# Start ID: 0, Goal ID: 26
# Start Coordinates: (150, 150), Goal Coordinates: (2880, 150)
# Start Node Edges: {27: 1}
# Goal Node Edges: {25: 1, 53: 1}
# Connection: 0 -> 27
# Connection: 27 -> 54
# Connection: 54 -> 81
# Connection: 81 -> 108
# Connection: 108 -> 135
# Connection: 135 -> 162
# Connection: 162 -> 189
# Connection: 189 -> 216
# Connection: 216 -> 243
# Connection: 243 -> 270
# Connection: 270 -> 297
# Connection: 297 -> 324
# Connection: 324 -> 325
# Connection: 325 -> 352
# Connection: 352 -> 353
# Connection: 353 -> 354
# Connection: 354 -> 355
# Connection: 355 -> 356
# Connection: 356 -> 357
# Connection: 357 -> 358
# Connection: 358 -> 331
# Connection: 331 -> 304
# Connection: 304 -> 277
# Connection: 277 -> 250
# Connection: 250 -> 223
# Connection: 223 -> 196
# Connection: 196 -> 169
# Connection: 169 -> 142
# Connection: 142 -> 115
# Connection: 115 -> 88
# Connection: 88 -> 61
# Connection: 61 -> 34
# Connection: 34 -> 35
# Connection: 35 -> 36
# Connection: 36 -> 37
# Connection: 37 -> 38
# Connection: 38 -> 39
# Connection: 39 -> 40
# Connection: 40 -> 41
# Connection: 41 -> 42
# Connection: 42 -> 43
# Connection: 43 -> 44
# Connection: 44 -> 45
# Connection: 45 -> 46
# Connection: 46 -> 73
# Connection: 73 -> 100
# Connection: 100 -> 127
# Connection: 127 -> 154
# Connection: 154 -> 181
# Connection: 181 -> 180
# Connection: 180 -> 207
# Connection: 207 -> 234
# Connection: 234 -> 261
# Connection: 261 -> 288
# Connection: 288 -> 315
# Connection: 315 -> 316
# Connection: 316 -> 343
# Connection: 343 -> 344
# Connection: 344 -> 345
# Connection: 345 -> 346
# Connection: 346 -> 373
# Connection: 373 -> 374
# Connection: 374 -> 375
# Connection: 375 -> 376
# Connection: 376 -> 349
# Connection: 349 -> 350
# Connection: 350 -> 323
# Connection: 323 -> 296
# Connection: 296 -> 269
# Connection: 269 -> 242
# Connection: 242 -> 215
# Connection: 215 -> 188
# Connection: 188 -> 161
# Connection: 161 -> 134
# Connection: 134 -> 107
# Connection: 107 -> 80
# Connection: 80 -> 53
# Connection: 53 -> 26

# %%
# Cell 6: Generate Command String from Path with Corrected Logic

def generate_command_string(path):
    command_string = "f"  # Start with a forward movement, since the robot always moves forward initially
    
    for i in range(1, len(path) - 1):
        prev_node = path[i - 1]
        current_node = path[i]
        next_node = path[i + 1]
        
        prev_diff = current_node - prev_node
        next_diff = next_node - current_node
        
        if prev_diff == 27 and next_diff == 1:
            command_string += "l"  # Turn left to move right
        elif prev_diff == -27 and next_diff == -1:
            command_string += "l"  # Turn left to move left
        elif prev_diff == 1 and next_diff == -27:
            command_string += "l"  # Turn left to move up
        elif prev_diff == -1 and next_diff == 27:
            command_string += "l"  # Turn left to move down
        elif prev_diff == 27 and next_diff == -1:
            command_string += "r"  # Turn right to move left
        elif prev_diff == -27 and next_diff == 1:
            command_string += "r"  # Turn right to move right
        elif prev_diff == 1 and next_diff == 27:
            command_string += "r"  # Turn right to move down
        elif prev_diff == -1 and next_diff == -27:
            command_string += "r"  # Turn right to move up
        command_string += "f"  # After turning, move forward
        
    return command_string  # Remove the extra forward move at the end

# Generate the command string based on the path from cell 5
if path:
    command_string = generate_command_string(path)
    print("Generated Command String:")
    print(command_string)
else:
    print("No path found, unable to generate command string.")
# Out:
# Generated Command String:
# fffffffffffflfrflfffffflffffffffffffrffffffffffffrfffffrflffffflfrflfffrflffflfrflffffffffffff
